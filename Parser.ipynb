# %%
import pandas as pd 
import numpy as np

# %%
data = pd.read_csv('EURUSD1_new.csv', sep=',', names=['Time', 'Open', 'Max', 'Min', 'Close', 'Value'])

# %%
del data['Time']

# %%
data_array = data.values
data_array_upd = data_array.reshape(6500, 50)
data_array_upd.shape
data_array_frame = pd.DataFrame(data_array_upd)
data_array_frame
# Out:
#            0        1        2        3      4        5        6        7   \
# 0     1.12933  1.12944  1.12921  1.12929  189.0  1.12930  1.12943  1.12922
# 1     1.12921  1.12926  1.12917  1.12922  117.0  1.12923  1.12934  1.12915
# 2     1.12953  1.12963  1.12953  1.12962   51.0  1.12965  1.12966  1.12940
# 3     1.12966  1.12969  1.12961  1.12968   94.0  1.12968  1.12968  1.12961
# 4     1.12982  1.12982  1.12977  1.12978   65.0  1.12977  1.12990  1.12971
# 5     1.13002  1.13007  1.13002  1.13006   43.0  1.13006  1.13006  1.13005
# 6     1.13003  1.13008  1.12999  1.13007   72.0  1.13006  1.13011  1.13003
# 7     1.13014  1.13026  1.13010  1.13022  107.0  1.13023  1.13033  1.13020
# 8     1.12978  1.12979  1.12962  1.12964  103.0  1.12965  1.12987  1.12963
# 9     1.13010  1.13020  1.12997  1.13003   99.0  1.13003  1.13003  1.12976
# 10    1.12947  1.12952  1.12933  1.12939  107.0  1.12939  1.12951  1.12933
# ...

# %%
data_array_frame.to_csv('EURUSD1_new_pars_value.csv', sep=',', index=False, header=False)

# %%
data_process = pd.read_csv('EURUSD1_new_pars_value.csv', sep=',', names=['GlobalOpen', 'Max1', 'Min1', 'Close1', 'Value1', 'Open2', 'Max2', 'Min2', 'Close2', 'Value2', 'Open3', 'Max3', 'Min3', 'Close3', 'Value3','Open4', 'Max4', 'Min4', 'Close4', 'Value4','Open5', 'Max5', 'Min5', 'Close5', 'Value5','Open6', 'Max6', 'Min6', 'Close6', 'Value6','Open7', 'Max7', 'Min7', 'Close7', 'Value7','Open8', 'Max8', 'Min8', 'Close8', 'Value8','Open9', 'Max9', 'Min9', 'Close9', 'Value9','Open10', 'Max10', 'Min10', 'GlobalClose', 'Value10'])

# %%
ii = 0
y_list = []
for i in data_process.GlobalOpen:
    if (data_process['GlobalClose'].values[ii] > i):
        y_list.append(1)
    else:
        y_list.append(0)
    ii+=1

# %%
# Out:
#       0
# 0     0
# 1     1
# 2     1
# 3     1
# 4     1
# 5     0
# 6     1
# 7     0
# 8     1
# 9     0
# 10    0
# 11    0
# 12    0
# 13    1
# 14    0
# 15    0
# 16    0
# 17    1
# 18    0
# 19    1
# 20    1
# 21    1
# 22    0
# 23    0
# 24    0
# 25    1
# 26    0
# 27    1
# 28    1
# 29    1
# ...  ..
# 6470  1
# 6471  0
# 6472  1
# 6473  1
# 6474  1
# 6475  1
# 6476  0
# 6477  0
# 6478  1
# 6479  1
# 6480  0
# 6481  1
# 6482  1
# 6483  0
# 6484  0
# 6485  0
# 6486  0
# 6487  1
# 6488  1
# 6489  0
# 6490  0
# 6491  0
# 6492  0
# 6493  0
# 6494  1
# 6495  0
# 6496  1
# 6497  0
# 6498  1
# 6499  1
#
# [6500 rows x 1 columns]
